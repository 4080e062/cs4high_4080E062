# %% [markdown]
# <a href="https://colab.research.google.com/github/4080e062/cs4high_4080E062/blob/master/python/store_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 電子產品販賣

# %%
# tt編號 a價格變數 u購買數量 f總價格 i是否繼續 b是否選擇 h正確與否

print("1.碟片 2.滑鼠 3鍵盤")
print("  100    350   800")
i = 0
f = 0

while i == 0:
  while i == 0:
    tt=int(input("輸入購買商品編號:"))
    if tt == 1:
      a = 100
    elif tt == 2:
      a = 350
    elif tt == 3:
      a = 800
    else :
      print("請輸入正確編碼")
      break
    print()
    u = int(input("輸入購買數量"))
    f = a * u + f
    b = input("是否繼續購買y/n:  ")
    if b == "n":
      i = 1  
    
print("總共是:",+f)
# Out:
# 1.碟片 2.滑鼠 3鍵盤
#   100    350   800
# 輸入購買商品編號:1
#
# 輸入購買數量1
# 是否繼續購買y/n:  y
# 輸入購買商品編號:2
#
# 輸入購買數量1
# 是否繼續購買y/n:  y
# 輸入購買商品編號:6
# 請輸入正確編碼
# 輸入購買商品編號:3
#
# 輸入購買數量0
# 是否繼續購買y/n:  n
# 總共是: 450
